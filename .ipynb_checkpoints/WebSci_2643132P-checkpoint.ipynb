# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

# %%
# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
# from gensim.utils import lemmatize, simple_preprocess
from gensim.utils import  simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Esha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
# Import Dataset
#The 20 newsgroups dataset comprises around 18000 newsgroups posts on 20 topics
df = pd.read_csv('./tweets/tweets.csv')
# df = df.loc[df.target_names.isin(['soc.religion.christian', 'rec.sport.hockey', 'talk.politics.mideast', 'rec.motorcycles']) , :]
print(df.shape)  #> (2361, 3)
df.head()
# Out:
# (10001, 5)
#                    _id         username  \
# 0  1621600585291014145    realJackEason
# 1  1621600584360153088  ManojKu40226010
# 2  1621600585358233600       TansyWatts
# 3  1621600585391783943    Green_Man1984
# 4  1621600586020933632   bruis3pristin3
#
#                                                 text    qScore    nScore
# 0  @pansexualflower Criterion certainly have US r...  0.613271  2.934114
# 1  🇨🇳 🇺🇸 #China\n#Chinese #Foreign #Ministry said...  0.446642 -2.994406
# 2  “As they began to understand the children’s op...  0.609156  1.772004
# 3  Excess Deaths Skyrocket Again In England And W...  0.608929 -1.639187
# 4  @altgirlalterego scotland, seychelles, syria, ...  0.608089 -0.254614

# %%
def sent_to_words(sentences):
    for sent in sentences:
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert to list
data = df.text.values.tolist()
data_words = list(sent_to_words(data))
print(data_words[:1])

from platform import python_version
print(python_version())
# Out:
# [['criterion', 'certainly', 'have', 'us', 'rights', 'to', 'the', 'restoration', 'but', 'very', 'unlikely', 'they', 'have', 'any', 'claim', 'to', 'uk', 'uhd', 'rights', 'alone', 'this', 'seems', 'more', 'like', 'cost', 'analysis', 'decision', 'by', 'the', 'bfi', 'or', 'else', 'they', 'determined', 'the', 'new', 'restoration', 'doesnt', 'merit', 'for', 'home', 'release', 'which', 'would', 'be', 'odd']]
# 3.11.2

# %%
#Lemmatisation in linguistics is the process of grouping together the inflected forms of a word so they can be analysed as a single item, identified by the word's lemma, or dictionary form.

# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

import en_core_web_sm
nlp = en_core_web_sm.load()

#!python3 -m spacy download en_core_web_md 
# !python3 -m spacy download en  # run in terminal once
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
   # nlp = spacy.load('en', disable=['parser', 'ner'])
    nlp = spacy.load("en_core_web_sm")
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!

# %%
data_ready
# Out:
# [['criterion',
#   'certainly',
#   'restoration',
#   'unlikely',
#   'claim',
#   'alone',
#   'cost',
#   'analysis',
#   'decision',
#   'bfi',
#   'else',
#   'determine',
#   'new',
#   'restoration',
#   'merit',
#   'home',
#   'release',
#   'odd'],
#  ['weather', 'deviate', 'course', 'military', 'dubai', 'pjp', 'os'],
#  ['begin',
#   'understand',
#   'child',
#   'operational',
#   'scheme',
#   'purposeful',
#   'visit',
#   'collect',
#   'offer',
#   'child',
#   'love',
#   'child',
#   'lead',
#   'influence'],
#  ['excess_death',
#   'death',
#   'excess_death',
#   'register',
#   'wale',
#   'week',
#   'end',
#   'th',
#   'year',
#   'average',
#   'happen'],
#  ['seychelle'],
#  ['horse_race',
#   'history',
#   'today',
#   'race',
#   'https',
#   'day',
#   'horse_race',
#   'news',
#   'history',
#   'extensive',
#   'horse',
#   'bet',
#   'news',
#   'archive',
#   'present',
#   'thoroughbred',
#   'race',
#   'action',
#   'australian',
#   'overseas',
#   'racing',
#   'news',
#   'history',
#   'gnko'],
#  ['ridiculous',
#   'service',
#   'store',
#   'remember',
#   'order',
#   'manager',
#   'treat',
#   'disrespect',
#   'staff',
#   'wait',
#   'refund',
#   'apparently',
#   'promise'],
#  ['stream', 'watch', 'head', 'head', 'start', 'stadium', 'part'],
#  ['check', 'eye'],
#  ['fable',
#   'city',
#   'metaphysical',
#   'foundation',
#   'gradually',
#   'abandon',
#   'polity',
#   'become',
#   'ripe',
#   'takeover',
#   'icarian',
#   'yearn',
#   'reassertion',
#   'coherent',
#   'rational',
#   'conscience',
#   'stifle',
#   'convention'],
#  ['break', 'law', 'impunity', 'shame', 'hunt', 'unpk'],
#  ['giveaway'],
#  ['unionist',
#   'care',
#   'check',
#   'loss',
#   'power',
#   'law',
#   'include',
#   'law',
#   'abortion',
#   'force',
#   'assembly',
#   'sit',
#   'property',
#   'law',
#   'starter'],
#  ['lovely', 'gesture', 'cardiff'],
#  ['bring',
#   'unforgettable',
#   'memory',
#   'absolutely',
#   'perfect',
#   'rhapsody',
#   'epic',
#   'flight',
#   'love',
#   'look',
#   'heart',
#   'magnificent',
#   'back',
#   'day'],
#  ['great',
#   'way',
#   'start',
#   'day',
#   'beeznation',
#   'season',
#   'kick',
#   'tomorrow',
#   'cant_wait',
#   'join',
#   'subscriber',
#   'great',
#   'year',
#   'bet',
#   'dollar',
#   'weekend',
#   'month',
#   'race',
#   'full',
#   'analysis',
#   'include',
#   'weekly',
#   'https'],
#  ['couple',
#   'set',
#   'sale',
#   'win',
#   'scrum',
#   'send',
#   'high',
#   'ball',
#   'back',
#   'bear',
#   'deal',
#   'threat',
#   'well',
#   'send',
#   'ball',
#   'back',
#   'top',
#   'half',
#   'way'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['watch',
#   'polish',
#   'movie',
#   'never',
#   'allow',
#   'evil',
#   'rapist',
#   'woman',
#   'child',
#   'england'],
#  ['talk',
#   'indian',
#   'official',
#   'possible',
#   'later',
#   'year',
#   'accord',
#   'official',
#   'aware',
#   'discussion',
#   'person',
#   'brief',
#   'matter'],
#  ['bring', 'back', 'dodo', 'woolly', 'mammoth', 'next', 'stop', 'end'],
#  ['realise',
#   'context',
#   'bit',
#   'sus',
#   'maybe',
#   'account',
#   'fudge',
#   'prev',
#   'month',
#   'create',
#   'month',
#   'hopefully',
#   'qualified',
#   'look'],
#  ['blimey',
#   'ticket',
#   'next',
#   'week',
#   'email',
#   'fly',
#   'delay',
#   'warnock',
#   'town'],
#  ['baby',
#   'blanket',
#   'friend',
#   'look',
#   'face',
#   'tell',
#   'tie',
#   'bleed',
#   'wash',
#   'skl'],
#  ['check', 'item', 'msgewaih'],
#  ['maybe',
#   'glasgow',
#   'child',
#   'book',
#   'food',
#   'dog',
#   'long',
#   'love',
#   'give',
#   'excuse',
#   'visit',
#   'sophie',
#   'souffle',
#   'pancake',
#   'glasgowbookfest',
#   'still',
#   'hashtag'],
#  ['sound', 'consider', 'appoint', 'guy'],
#  ['secret',
#   'tape',
#   'catch',
#   'congressman',
#   'admitting',
#   'lie',
#   'give',
#   'botox',
#   'advice',
#   'congressman',
#   'admit',
#   'obviously',
#   'new',
#   'recording',
#   'conversation',
#   'prospective'],
#  ['listen',
#   'today',
#   'downland',
#   'racing',
#   'show',
#   'week',
#   'racing',
#   'preview',
#   'action'],
#  ['stream', 'watch', 'head', 'head', 'start', 'stadium', 'match', 'part'],
#  ['autism',
#   'adhd',
#   'airport',
#   'autism',
#   'airport',
#   'sit',
#   'call',
#   'gate',
#   'number',
#   'adhd',
#   'airport',
#   'sit',
#   'miss',
#   'hearing',
#   'gate',
#   'number',
#   'feck',
#   'excite',
#   'boarding',
#   'inpatient',
#   'que',
#   'long',
#   'autism',
#   'adhd'],
#  ['welcome', 'union'],
#  ['give',
#   'aid',
#   'red',
#   'nlaw',
#   'red',
#   'howitzer',
#   'next',
#   'tank',
#   'talk',
#   'world',
#   'weak',
#   'really',
#   'prigozhin',
#   'soon',
#   'enough'],
#  ['experience',
#   'amount',
#   'customer',
#   'service',
#   'call',
#   'add',
#   'compatible',
#   'battery',
#   'reset',
#   'booting'],
#  ['fear', 'monger'],
#  ['dry',
#   'clean',
#   'eraser',
#   'trick',
#   'look',
#   'bad',
#   'crumbly',
#   'heavy',
#   'stain',
#   'pal'],
#  ['humidity', 'wind', 'mph', 'pressure', 'rainfall', 'weather'],
#  ['luck', 'well', 'sure', 'achieve', 'goal'],
#  ['watch', 'always', 'block', 'shower', 'nt', 'tory'],
#  ['remember',
#   'first',
#   'time',
#   'excitedly',
#   'point',
#   'rainbow',
#   'friend',
#   'never',
#   'kind',
#   'thing'],
#  ['tory', 'care', 'wager', 'dividend', 'investment', 'energy', 'firm'],
#  ['low', 'deck', 'symposium', 'janeway', 'open', 'access', 'publish'],
#  ['thame',
#   'path',
#   'tree',
#   'chop',
#   'comment',
#   'application',
#   'plan',
#   'portal',
#   'application',
#   'number',
#   'revetment',
#   'application',
#   'morden',
#   'wharf',
#   'revetment'],
#  ['counter',
#   'lose',
#   'follower',
#   'downright',
#   'bully',
#   'fuck',
#   'lie',
#   'screw',
#   'people',
#   'speak',
#   'conservative',
#   'cancel',
#   'culture'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['daddy', 'play'],
#  ['torture',
#   'starve',
#   'child',
#   'partner',
#   'find',
#   'dead',
#   'prison',
#   'cell',
#   'sorry'],
#  ['show', 'late', 'leave', 'early', 'great', 'comedy'],
#  ['conservative', 'vote', 'socialist', 'upebpqfppj'],
#  ['title', 'princess', 'wale', 'divorce', 'tie'],
#  ['interesting', 'tweet', 'begin', 'co', 'fzwwlaxq'],
#  ['never',
#   'carol',
#   'hit',
#   'corrupt',
#   'tory',
#   'tell',
#   'truth',
#   'carol',
#   'put',
#   'english',
#   'medium',
#   'shame',
#   'carol',
#   'vorder',
#   'vote'],
#  ['sussex',
#   'haze',
#   'debuting',
#   'fruity',
#   'ddh',
#   'pale',
#   'craftbeer',
#   'craftnotcrap',
#   'indie',
#   'cumbria',
#   'notjustlake',
#   'beerkendal'],
#  ['talk',
#   'indian',
#   'official',
#   'possible',
#   'later',
#   'year',
#   'accord',
#   'official',
#   'aware',
#   'discussion',
#   'person',
#   'brief'],
#  ['course', 'week', 'hear', 'aspirational'],
#  ['move',
#   'leadership',
#   'nemesis',
#   'key',
#   'player',
#   'keep',
#   'trend',
#   'family',
#   'conservative',
#   'control',
#   'chief',
#   'man'],
#  ['shame', 'stuff'],
#  ['match',
#   'stamford_bridge',
#   'pm',
#   'screen',
#   'live',
#   'due',
#   'ban',
#   'televise',
#   'action',
#   'saturday',
#   'result',
#   'blackout',
#   'impose',
#   'article',
#   'regulation'],
#  ['shock',
#   'left_we',
#   'bias',
#   'effort',
#   'hide',
#   'anymore',
#   'part',
#   'effort',
#   'rejoin',
#   'install',
#   'labour',
#   'government'],
#  ['order', 'miss', 'stone', 'cold', 'stone', 'cold', 'miss', 'ridiculous'],
#  ['firm', 'hand'],
#  ['watch', 'conservative', 'respond', 'liberal', 'pull', 'amendment', 'abrb'],
#  ['firstly',
#   'ask',
#   'usual',
#   'question',
#   'people',
#   'vote',
#   'stay',
#   'join',
#   'referendum',
#   'stay',
#   'join',
#   'read',
#   'people',
#   'uk'],
#  ['prosperous',
#   'peaceful',
#   'amp',
#   'secure',
#   'work',
#   'possible',
#   'vote',
#   'god_bless',
#   'djk',
#   'rk'],
#  ['enjoy', 'luck'],
#  ['stone',
#   'sit',
#   'deliver',
#   'monologue',
#   'club',
#   'failing',
#   'especially',
#   'obviously',
#   'nail',
#   'fan',
#   'total',
#   'agreement'],
#  ['book',
#   'launch',
#   'event',
#   'join',
#   'author',
#   'pringle',
#   'launch',
#   'autobiography',
#   'place',
#   'power',
#   'adventure',
#   'person',
#   'interview'],
#  ['replay', 'red', 'coverage', 'tonight'],
#  ['often',
#   'wonder',
#   'explore',
#   'much',
#   'wale',
#   'great',
#   'transport',
#   'network',
#   'look',
#   'book',
#   'trip',
#   'harlech',
#   'discover',
#   'cheap'],
#  ['check', 'victor', 'race', 'website', 'detail', 'satisfy'],
#  ['cheesecake', 'look', 'box', 'well', 'real', 'life'],
#  ['hold',
#   'ransom',
#   'billionaire',
#   'trade',
#   'unionist',
#   'torie',
#   'russian',
#   'money',
#   'problem'],
#  ['suki',
#   'calder',
#   'rock',
#   'day',
#   'friendly',
#   'chat',
#   'great',
#   'rock',
#   'music',
#   'smart',
#   'speaker',
#   'remember',
#   'play',
#   'radio'],
#  ['number'],
#  ['never',
#   'fact',
#   'road',
#   'show',
#   'actual',
#   'plot',
#   'consist',
#   'secret',
#   'steal',
#   'purse'],
#  ['enjoy'],
#  ['find', 'pleasing', 'read', 'suspect', 'enjoy'],
#  ['love',
#   'find',
#   'random',
#   'aberdeen',
#   'player',
#   'red',
#   'funny',
#   'yer',
#   'sit',
#   'rival',
#   'watch',
#   'win',
#   'yet',
#   'treble',
#   'pleased',
#   'haha'],
#  ['gt_gt',
#   'new_york',
#   'overseas',
#   'voter',
#   'call',
#   'write',
#   'nys',
#   'senator',
#   'floor',
#   'vote',
#   'bill',
#   'enable',
#   'overseas',
#   'voter',
#   'return',
#   'ballot',
#   'electronically',
#   'co'],
#  ['bother',
#   'local',
#   'councilor',
#   'labour',
#   'great',
#   'area',
#   'imagine',
#   'general',
#   'next',
#   'time',
#   'miss',
#   'trick',
#   'somewhere'],
#  ['ask', 'process', 'place', 'accuse'],
#  ['hate', 'shower', 'pay', 'hour', 'town'],
#  ['conservative', 'victim', 'year', 'systemic', 'white', 'ask', 'wzfhdjb'],
#  ['tear',
#   'hand',
#   'pace',
#   'episode',
#   'leave',
#   'hand',
#   'shancai',
#   'scene',
#   'continue',
#   'watch'],
#  ['bring', 'bolling'],
#  ['exactly', 'attitude', 'sunak', 'parasite', 'love', 'give', 'hope'],
#  ['conservative', 'really', 'live', 'fear', 'constantly', 'sad'],
#  ['together', 'produce', 'perfect', 'storm', 'today'],
#  ['native', 'dorrie', 'buy', 'comb'],
#  ['tell', 'week', 'ago'],
#  ['support',
#   'people',
#   'live',
#   'terminal',
#   'illness',
#   'help',
#   'people',
#   'death',
#   'die'],
#  ['thame', 'water', 'problem', 'access', 'road', 'problem', 'location', 'rb'],
#  ['banker', 'bonus', 'unlimited', 'truss', 'sunak'],
#  ['opportunity', 'talk', 'research', 'scicomm', 'uobengage', 'ahpresearch'],
#  ['still', 'vote', 'snp'],
#  ['difficult',
#   'enough',
#   'black',
#   'ex',
#   'player',
#   'badge',
#   'desire',
#   'manage',
#   'elite',
#   'level',
#   'enough',
#   'black',
#   'people',
#   'reffe',
#   'headline',
#   'term',
#   'black',
#   'list',
#   'represent',
#   'management',
#   'element',
#   'prejudice'],
#  ['amount',
#   'money',
#   'spend',
#   'video',
#   'pop',
#   'memorial',
#   'park',
#   'cent',
#   'drone'],
#  ['delight', 'fan', 'mobile'],
#  ['stable', 'auburn'],
#  ['handpicke',
#   'first',
#   'become',
#   'finance',
#   'party',
#   'base',
#   'election',
#   'follow',
#   'death',
#   'iji',
#   'especially',
#   'vote',
#   'name',
#   'zia',
#   'objective'],
#  ['still', 'sell', 'car'],
#  ['back',
#   'old',
#   'man',
#   'today',
#   'love',
#   'immigrant',
#   'well',
#   'bump',
#   'space',
#   'leave',
#   'alone',
#   'free',
#   'speech'],
#  ['big', 'freaking', 'baby', 'welcome', 'truck', 'series'],
#  ['ever',
#   'hear',
#   'second',
#   'opinion',
#   'fairly',
#   'standard',
#   'medical',
#   'practice'],
#  ['perhaps',
#   'point',
#   'government',
#   'position',
#   'pertain',
#   'indigenous',
#   'community',
#   'clean',
#   'water',
#   'ill',
#   'wait'],
#  ['half', 'animal', 'die', 'preventable', 'barn', 'fire'],
#  ['pierre', 'cut', 'cheque', 'hate', 'conservative'],
#  ['build',
#   'private',
#   'business',
#   'opposition',
#   'build',
#   'state',
#   'pay',
#   'back',
#   'cost',
#   'first',
#   'year',
#   'great',
#   'port',
#   'canal',
#   'open',
#   'great',
#   'lake',
#   'prosperity'],
#  ['shadow'],
#  ['egregious',
#   'smithsonian',
#   'eject',
#   'pro',
#   'life',
#   'kid',
#   'conservative',
#   'fight'],
#  ['exclusive',
#   'german',
#   'football',
#   'coach',
#   'unmasked',
#   'russian',
#   'double',
#   'agent'],
#  ['fan', 'change'],
#  ['ticket',
#   'office',
#   'club',
#   'shop',
#   'today',
#   'look',
#   'much',
#   'well',
#   'play',
#   'rochdale'],
#  ['never', 'elect', 'ever', 'state', 'allot'],
#  ['tweet'],
#  [],
#  ['part', 'live', 'new_york_city', 'laundry', 'building'],
#  ['hurl'],
#  ['spend', 'much', 'money', 'player', 'pitch', 'horrendous'],
#  ['suspect', 'ioz'],
#  ['call', 'central', 'station', 'general', 'information', 'inquire', '颜色陪玩'],
#  ['main', 'difference'],
#  ['health',
#   'union',
#   'suspend',
#   'welsh',
#   'government',
#   'improve',
#   'pay',
#   'offer'],
#  ['woman', 'child', 'bearing', 'age', 'fourth', 'let', 'alone', 'sixth'],
#  ['show', 'replay'],
#  ['actually',
#   'lose',
#   'control',
#   'liberal',
#   'socialist',
#   'progressive',
#   'marxist',
#   'since',
#   'wreck',
#   'enormous',
#   'wrecked',
#   'inflation',
#   'open',
#   'border',
#   'flood',
#   'drug',
#   'criminal',
#   'asylum',
#   'job',
#   'seeker',
#   'open'],
#  ['work',
#   'covent',
#   'garden',
#   'installation',
#   'word',
#   'rainbow',
#   'decorate',
#   'heals',
#   'bloomsbury',
#   'festival',
#   'art',
#   'artist',
#   'artist',
#   'nctixalgyo'],
#  ['hope',
#   'big',
#   'attendance',
#   'tomorrow',
#   'night',
#   'big',
#   'night',
#   'town',
#   'tyrone',
#   'hurl'],
#  ['find',
#   'stable',
#   'government',
#   'nation',
#   'shackle',
#   'imagine',
#   'england',
#   'alone'],
#  ['name', 'gather', 'possible', 'create', 'environment', 'reason'],
#  ['liverpool', 'add', 'new', 'player', 'axe', 'ipyk'],
#  ['urge',
#   'give',
#   'people',
#   'year',
#   'notice',
#   'increase',
#   'state',
#   'pension',
#   'age'],
#  ['certainly',
#   'window',
#   'last',
#   'respect',
#   'show',
#   'club',
#   'team',
#   'mate',
#   'pleasing',
#   'proud',
#   'work',
#   'sufc',
#   'report',
#   'ucvvxozmty'],
#  ['benchmarker', 'brilliant', 'guy'],
#  ['match',
#   'pick',
#   'late',
#   'fa_cup',
#   'fifth',
#   'round',
#   'tv',
#   'selection',
#   'gtfc',
#   'stevenagefc'],
#  ['absolutely',
#   'beautiful',
#   'aldi',
#   'air',
#   'fryer',
#   'snack',
#   'viral',
#   'https',
#   'co',
#   'pmoefo'],
#  ['great', 'watch', 'live', 'app'],
#  ['eagle', 'farm', 'racing', 'king', 'kapa', 'hollywoodbet', 'horse', 'tip'],
#  ['auburn', 'girl', 'auburn', 'live_broadcast'],
#  ['win',
#   'huge',
#   'parimatch',
#   'enhance',
#   'odd',
#   'load',
#   'new',
#   'customer',
#   'offer',
#   'apply',
#   'begambleaware',
#   'ad',
#   'odd',
#   'change',
#   'bet',
#   'limit',
#   'apply',
#   'sjumauehie'],
#  ['include',
#   'labour',
#   'government',
#   'fair',
#   'play',
#   'respond',
#   'present',
#   'however',
#   'political',
#   'ever',
#   'part',
#   'story',
#   'protest',
#   'select',
#   'move',
#   'dial'],
#  ['boy', 'mole', 'fox', 'horse', 'air', 'far', 'https'],
#  ['underway',
#   'tomorrow',
#   'year',
#   'drought',
#   'principality',
#   'stadium',
#   'catch',
#   'update',
#   'live',
#   'afternoon',
#   'pm'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['film', 'street', 'new_york'],
#  ['rest', 'peace', 'name', 'live', 'legend'],
#  ['shirt',
#   'tune',
#   'personalise',
#   'gift',
#   'sport',
#   'travel',
#   'adventure',
#   'cadeau_sport',
#   'fashion',
#   'https'],
#  ['flight', 'attendant', 'loveaviation'],
#  ['honeoye', 'falls_new_york', 'wind_gust'],
#  ['endeavour',
#   'show',
#   'game',
#   'possible',
#   'nation',
#   'tournament',
#   'kicking',
#   'opening',
#   'match',
#   'saturday',
#   'include',
#   'calcutta',
#   'check',
#   'centre',
#   'website',
#   'opening',
#   'time',
#   'week'],
#  ['child',
#   'pressure',
#   'mother',
#   'ask',
#   'well',
#   'child',
#   'settle',
#   'elder',
#   'buy',
#   'work',
#   'climate',
#   'damp',
#   'people',
#   'foreigner',
#   'cold'],
#  ['define'],
#  ['look',
#   'affordable',
#   'professional',
#   'support',
#   'offer',
#   'support',
#   'security',
#   'manage',
#   'service',
#   'small',
#   'medium',
#   'size',
#   'business',
#   'itsolution',
#   'itsupport',
#   'itservice',
#   'business'],
#  ['tweet',
#   'picture',
#   'jack',
#   'final',
#   'involve',
#   'aberdeen',
#   'suppose',
#   'absolutely',
#   'fuck',
#   'celebrate',
#   'shagg'],
#  ['enter', 'lottery', 'ticket', 'tap', 'enter', 'vih'],
#  ['suggest', 'course', 'mindfulness', 'mental', 'wellbeing', 'look'],
#  ['call', 'central', 'station', 'general', 'information', 'inquire', '颜色陪玩'],
#  ['short', 'trip', 'great', 'weekend'],
#  ['wind_gust'],
#  ['alxkig'],
#  ['welcome',
#   'francis',
#   'historic',
#   'visit',
#   'accompany',
#   'team',
#   'archbishop',
#   'welly',
#   'greenshield',
#   'bgece'],
#  ['hospitality',
#   'team',
#   'member',
#   'apprentice',
#   'level',
#   'ltd',
#   'intermediate',
#   'level',
#   'apply',
#   'day',
#   'leave',
#   'bzoi',
#   'apprenticeship',
#   'manchesterjob'],
#  ['eeqg'],
#  ['enter', 'giveaway', 'copy'],
#  ['day', 'race', 'live', 'tune', 'enjoy', 'afternoon', 'racing'],
#  ['tempting',
#   'let',
#   'small',
#   'carpet',
#   'stain',
#   'sit',
#   'act',
#   'quickly',
#   'save',
#   'headache',
#   'road',
#   'help',
#   'advice',
#   'touch'],
#  ['sell', 'tell', 'fuck', 'end', 'cantona', 'horrible', 'cunt'],
#  ['racing',
#   'look',
#   'saturday',
#   'race',
#   'interest',
#   'watch',
#   'market',
#   'sign',
#   'confidence',
#   'ahead',
#   'horserace'],
#  ['start', 'salary', 'teach', 'advertise', 'teach', 'year'],
#  ['heart', 'race', 'shortness', 'breath', 'double', 'medicine', 'rest'],
#  ['knit',
#   'wool',
#   'woollen',
#   'craft',
#   'clothe',
#   'clothing',
#   'handmade_craft',
#   'craft',
#   'jacket',
#   'knit',
#   'child',
#   'boy',
#   'girl',
#   'baby',
#   'vintage'],
#  ['knit',
#   'wool',
#   'woollen',
#   'craft',
#   'clothe',
#   'clothing',
#   'handmade_craft',
#   'craft',
#   'jacket',
#   'knit',
#   'child',
#   'boy',
#   'girl',
#   'baby',
#   'vintage'],
#  ['knit',
#   'wool',
#   'woollen',
#   'craft',
#   'clothe',
#   'clothing',
#   'handmade_craft',
#   'craft',
#   'jacket',
#   'knit',
#   'child',
#   'boy',
#   'girl',
#   'baby',
#   'vintage',
#   'cdj'],
#  ['let', 'agree', 'rum', 'lad', 'though'],
#  ['live', 'disagree'],
#  ['news',
#   'flash',
#   'politician',
#   'actor',
#   'degree',
#   'liberal',
#   'act',
#   'govt',
#   'average',
#   'low',
#   'income',
#   'people',
#   'conservative',
#   'act',
#   'limited',
#   'govt',
#   'constitutional',
#   'usually',
#   'full',
#   'crap'],
#  ['studio', 'flat', 'ask', 'price', 'https', 'rhwvjwlaxp'],
#  ['strike', 'resemblance', 'stanley'],
#  ['police', 'vetting', 'database', 'vow', 'follow', 'case', 'rapist'],
#  ['former',
#   'striker',
#   'brian',
#   'back',
#   'top',
#   'chart',
#   'embrace',
#   'new',
#   'unrecognisable',
#   'look'],
#  ['ticket', 'leave', 'month', 'kick', 'miss'],
#  ['demonstrate',
#   'blind',
#   'spot',
#   'interview',
#   'genuinely',
#   'refuse',
#   'admit',
#   'show'],
#  ['really', 'still'],
#  ['humidity',
#   'light',
#   'lux',
#   'dark',
#   'rain_mm',
#   'today',
#   'wind_speed',
#   'mph',
#   'wind_gust',
#   'mph',
#   'qual',
#   'pm',
#   'excellent',
#   'worsen'],
#  [],
#  ['play', 'manutd', 'dicey'],
#  ['sign', 'share'],
#  ['vocaloid', 'hatsune', 'miku', 'racing', 'ver'],
#  ['train'],
#  ['leather', 'chelsea', 'boot', 'shoe', 'iheilgdln'],
#  ['second',
#   'half',
#   'way',
#   'portman',
#   'road',
#   'town',
#   'fifth',
#   'round',
#   'massive',
#   'ask',
#   'young',
#   'red',
#   'turn',
#   'dann',
#   'gyimah',
#   'second',
#   'half',
#   'scdsgiskew'],
#  ['genuine', 'omega', 'speedmaster', 'racing', 'dial', 'cal', 'iwvl'],
#  ['woman', 'trefoil', 'mule', 'clutch', 'bag', 'new', 'size', 'dg'],
#  ['way',
#   'look',
#   'currently',
#   'manager',
#   'black',
#   'black',
#   'population',
#   'currently',
#   'quite',
#   'well'],
#  ['cost',
#   'synthetic',
#   'lawn',
#   'garden',
#   'kew',
#   'synthetic',
#   'garden',
#   'grass',
#   'cost',
#   'kew'],
#  ['day', 'prep', 'trip', 'new_york', 'couple', 'day'],
#  ['adelaide', 'wharf', 'ask', 'price', 'https'],
#  ['night',
#   'oscar',
#   'fotka',
#   'quiz',
#   'well',
#   'underway',
#   'team',
#   'tuck',
#   'rzgaviio'],
#  ['check', 'seasonal', 'work', 'visa', 'announce', 'check'],
#  ['sorry',
#   'manager',
#   'apologise',
#   'ace',
#   'miss',
#   'dream',
#   'ranger',
#   'move',
#   'ranger',
#   'rangersfamily'],
#  ['sorely',
#   'dumbe',
#   'society',
#   'morally',
#   'degenerate',
#   'fool',
#   'skip',
#   'globally'],
#  ['slaughter',
#   'almost',
#   'unbearable',
#   'pain',
#   'war',
#   'participant',
#   'difficult',
#   'overcome',
#   'choice',
#   'difficulty',
#   'resultant',
#   'less',
#   'hardship',
#   'sure',
#   'summon',
#   'tolerance',
#   'fortitude'],
#  ['tomorrow'],
#  ['war',
#   'really',
#   'horrify',
#   'organisation',
#   'show',
#   'ukraine',
#   'man',
#   'give',
#   'flag',
#   'gun',
#   'week',
#   'training',
#   'shot',
#   'fight',
#   'high',
#   'spec',
#   'gun',
#   'nvg',
#   'mapping'],
#  ['pro',
#   'tip',
#   'globalist',
#   'act',
#   'defend',
#   'nation',
#   'imperial',
#   'footprint',
#   'mean',
#   'global',
#   'dominion',
#   'manif',
#   'destiny'],
#  ['vote', 'back', 'day'],
#  ['man', 'scottish', 'labour', 'leader', 'member', 'extreme', 'wing', 'cabal'],
#  ['sell', 'sabrina', 'ticket', 'package', 'info'],
#  ['look',
#   'much',
#   'profit',
#   'overseas',
#   'proud',
#   'business',
#   'shaft',
#   'hard',
#   'leave',
#   'really',
#   'idea'],
#  ['bigbangerz', 'jump', 'surely'],
#  ['battle', 'gender', 'male', 'thing', 'conservative', 'really', 'transgere'],
#  ['former',
#   'court',
#   'appeal',
#   'judge',
#   'appoint',
#   'chair',
#   'review',
#   'culture',
#   'behaviour',
#   'welsh'],
#  ['identify', 'day'],
#  ['wing',
#   'conservative',
#   'claim',
#   'follow',
#   'liverpool',
#   'fc',
#   'always',
#   'odd',
#   'creature'],
#  ['idea',
#   'facinate',
#   'broad',
#   'thinker',
#   'probably',
#   'friend',
#   'long',
#   'talk'],
#  ['wookiepedia', 'fan', 'disney'],
#  ['illiterate', 'struggle'],
#  ['episode',
#   'greek',
#   'bear',
#   'gift',
#   'scifi',
#   'toshiko',
#   'give',
#   'alien',
#   'pendant',
#   'enable',
#   'hear',
#   'people',
#   'thought',
#   'jctokhljjw'],
#  ['departed', 'track', 'flight', 'link'],
#  ['race', 'car'],
#  ['harrogate',
#   'lovely',
#   'tory',
#   'stronghold',
#   'bettys',
#   'tea',
#   'room',
#   'love',
#   'ill',
#   'bet',
#   'mortgage',
#   'elsewhere'],
#  ['live',
#   'look',
#   'iowan',
#   'weekend',
#   'seriously',
#   'thing',
#   'new_york',
#   'reaction',
#   'vpjgd',
#   'vnfu'],
#  ['live'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['put',
#   'tin',
#   'foil',
#   'hat',
#   'back',
#   'wank',
#   'mate',
#   'part',
#   'militia',
#   'time',
#   'obvs',
#   'never'],
#  ['public',
#   'service',
#   'completely',
#   'bleed',
#   'dry',
#   'conservative',
#   'public',
#   'health',
#   'service',
#   'carve',
#   'speak',
#   'inflation',
#   'high',
#   'place',
#   'future',
#   'young',
#   'people',
#   'country',
#   'stand'],
#  ['watch'],
#  ['top',
#   'flight',
#   'compensation',
#   'company',
#   'luxury',
#   'magazine',
#   'contact',
#   'group',
#   'detail'],
#  ['weak', 'attempt', 'smear', 'master', 'tell', 'ange'],
#  ['doubt', 'team', 'surprised', 'end', 'abroad', 'somewhere'],
#  ['sure',
#   'green',
#   'tax',
#   'help',
#   'find',
#   'people',
#   'concern',
#   'high',
#   'crime',
#   'rate'],
#  ['support',
#   'campaign',
#   'yorkshire',
#   'newspaper',
#   'support',
#   'yorkshire',
#   'title',
#   'south',
#   'yorkshire',
#   'mayoral',
#   'launch',
#   'independent',
#   'enquiry',
#   'closure',
#   'local',
#   'airport',
#   'lesson',
#   'learn'],
#  ['brother',
#   'actually',
#   'poison',
#   'jab',
#   'order',
#   'able',
#   'drink',
#   'cause',
#   'regret',
#   'talk'],
#  ['bandmate',
#   'actually',
#   'show',
#   'studio',
#   'sesh',
#   'instead',
#   'turn',
#   'location'],
#  ['love',
#   'send',
#   'request',
#   'rush',
#   'little',
#   'piggys',
#   'send',
#   'tag',
#   'request',
#   'findom',
#   'finsub',
#   'slave',
#   'paypig',
#   'wifehate',
#   'blackmailing'],
#  ['appreciate',
#   'great',
#   'reporting',
#   'editor',
#   'often',
#   'call',
#   'minister',
#   'official',
#   'fact',
#   'complain',
#   'anglosphere',
#   'medium',
#   'buy',
#   'fantasy'],
#  ['night',
#   'vote',
#   'entry',
#   'previous',
#   'esc',
#   'edition',
#   'host',
#   'semifinal',
#   'change',
#   'lifetime',
#   'th'],
#  ['listen',
#   'side',
#   'debate',
#   'form',
#   'opinion',
#   'mind',
#   'conservative',
#   'always',
#   'wrong',
#   'side',
#   'debate'],
#  ['artificial',
#   'grass',
#   'price',
#   'nursery',
#   'play',
#   'area',
#   'synthetic',
#   'grass',
#   'play',
#   'area'],
#  ['parent', 'stun', 'toddler', 'camberwell', 'nursery', 'morning'],
#  ['first',
#   'visit',
#   'year',
#   'omg',
#   'food',
#   'outstanding',
#   'fried',
#   'prawn',
#   'revelation',
#   'cheek',
#   'hubby',
#   'love',
#   'goat',
#   'cheese',
#   'beautiful',
#   'black',
#   'pudding',
#   'liver',
#   'classic',
#   'soon',
#   'dku'],
#  ['date', 'tour', 'release', 'cardiff', 'date', 'wm'],
#  ['travel',
#   'careful',
#   'especially',
#   'evening',
#   'weekend',
#   'police',
#   'unmarke',
#   'car',
#   'write',
#   'ticket',
#   'extra',
#   'careful',
#   'birmingham'],
#  ['trent', 'live', 'christian', 'mum', 'sue', 'school', 'son', 'force'],
#  ['looking_forward', 'involved', 'year'],
#  ['close', 'personal', 'rein', 'new_york', 'style', 'deli', 'fine', 'flavor'],
#  ['legal',
#   'specialist',
#   'solicitor',
#   'family',
#   'law',
#   'conveyance',
#   'criminal',
#   'law',
#   'probate',
#   'matter',
#   'office',
#   'property',
#   'valuation',
#   'tool',
#   'call',
#   'vkxgf'],
#  ['entry',
#   'host',
#   'swarbrigg',
#   'love',
#   'rd',
#   'duskey',
#   'today',
#   'tomorrow',
#   'dawn',
#   'always',
#   'th'],
#  ['video',
#   'atmosphere',
#   'look',
#   'player',
#   'embrace',
#   'wale',
#   'challenge',
#   'close',
#   'cardiff',
#   'sixnation',
#   'co',
#   'ujiw'],
#  ['oxford', 'fjqdnuensw'],
#  ['corruption',
#   'tory',
#   'sleaze',
#   'corruption',
#   'threaten',
#   'global',
#   'reputation',
#   'conservative',
#   'conservative'],
#  ['yare'],
#  ['nation',
#   'give',
#   'top',
#   'priority',
#   'far',
#   'deprive',
#   'neglect',
#   'year',
#   'budget',
#   'underline',
#   'priority',
#   'deprive',
#   'key',
#   'guide',
#   'sentiment'],
#  ['let',
#   'include',
#   'man',
#   'already',
#   'loser',
#   'let',
#   'move',
#   'enjoy',
#   'love',
#   'sister',
#   'girllllll'],
#  ['love', 'glasgow', 'year', 'leave', 'new'],
#  ['review', 'toxic', 'people'],
#  ['nonsense', 'stilt', 'new', 'favourite'],
#  ['politician', 'allow', 'male', 'bear', 'rapist', 'women', 'prison'],
#  ['petition'],
#  ['turn',
#   'cheek',
#   'long',
#   'option',
#   'leave',
#   'cancel',
#   'conservative',
#   'long',
#   'time',
#   'fight',
#   'way',
#   'defeat',
#   'bully',
#   'punch',
#   'back',
#   'hide',
#   'middle',
#   'cowardice'],
#  ['esport', 'set', 'play', 'pm', 'respectively', 'esport'],
#  ['worldwide', 'profit', 'profit'],
#  ['conservative', 'balloon', 'time', 'grow', 'ball'],
#  ['video', 'ram', 'trx', 'trailer', 'racing'],
#  ['time',
#   'evaluate',
#   'current',
#   'amp',
#   'revamp',
#   'portfolio',
#   'fill',
#   'content',
#   'bring',
#   'value',
#   'brand',
#   'clean',
#   'set',
#   'sure',
#   'content',
#   'actually',
#   'bring',
#   'brand',
#   'ugc'],
#  ['watch',
#   'hit',
#   'radio',
#   'sportsnew',
#   'music',
#   'radio',
#   'tune',
#   'hit',
#   'onlineradio'],
#  ['child',
#   'young',
#   'people',
#   'diagnosable',
#   'mentalhealth',
#   'condition',
#   'th',
#   'support',
#   'raise',
#   'awareness',
#   'importance',
#   'child',
#   'young',
#   'people',
#   'learn'],
#  ['always', 'tell', 'people', 'first'],
#  ['sunak',
#   'bearded',
#   'emphasis',
#   'arrive',
#   'army',
#   'counter',
#   'strike',
#   'cartoon',
#   'relate',
#   'transportation',
#   'sector',
#   'strike',
#   'strike',
#   'railstrike'],
#  ['fight', 'death', 'hand', 'hubba', 'bubba'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['film', 'street', 'new_york'],
#  ['flounce', 'twitter', 'heat', 'artist'],
#  ['part', 'consider', 'rude'],
#  ['look',
#   'new',
#   'children',
#   'book',
#   'browse',
#   'brilliant',
#   'selection',
#   'huge',
#   'choice',
#   'book',
#   'include',
#   'sign',
#   'copy'],
#  ['top',
#   'oil',
#   'customer',
#   'nation',
#   'funnel',
#   'record',
#   'amount',
#   'fuel',
#   'sanctioned',
#   'product'],
#  ['new',
#   'small',
#   'plate',
#   'honey',
#   'soy',
#   'sauce',
#   'teamfleet',
#   'newmenu',
#   'proper',
#   'https',
#   'co',
#   'fatfabaok'],
#  ['excellent', 'excellent', 'implement', 'suppose'],
#  ['salute',
#   'tory',
#   'train',
#   'friend',
#   'brexitreality',
#   'nazi',
#   'train',
#   'camp',
#   'co',
#   'tuniuup'],
#  ['actually', 'homework', 'system', 'work'],
#  ['top',
#   'oil',
#   'customer',
#   'nation',
#   'funnel',
#   'record',
#   'amount',
#   'fuel',
#   'sanctioned',
#   'product'],
#  ['wish', 'well', 'pup'],
#  ['really',
#   'sorry',
#   'long',
#   'hold',
#   'time',
#   'speak',
#   'log',
#   'complaint',
#   'follow',
#   'link',
#   'help',
#   'add',
#   'much',
#   'information',
#   'team',
#   'investigate',
#   'amy',
#   'romuyg',
#   'iaf'],
#  ['appeal', 'parking', 'walk', 'leo', 'seo', 'allegedly', 'bree'],
#  ['new_york'],
#  ['extend',
#   'cold',
#   'weather',
#   'alert',
#   'forecast',
#   'call',
#   'temperature',
#   'drop',
#   'tonight',
#   'windchill',
#   'fall',
#   'similar',
#   'condition',
#   'continue',
#   'morning',
#   'hour',
#   'tmwxndk',
#   'pc'],
#  ['desperate',
#   'stuff',
#   'bring',
#   'denmark',
#   'discussion',
#   'tory',
#   'hard',
#   'vote'],
#  ['government',
#   'fail',
#   'back',
#   'pm',
#   'claim',
#   'patient',
#   'flow',
#   'fast',
#   'ever',
#   'full',
#   'fact',
#   'https',
#   'co'],
#  ['join',
#   'online',
#   'give',
#   'proper',
#   'tool',
#   'shape',
#   'live',
#   'regardless',
#   'age',
#   'expertise',
#   'join',
#   'historic',
#   'moment',
#   'together',
#   'create',
#   'bright',
#   'sustainable',
#   'future'],
#  ['wearredday',
#   'heart',
#   'health',
#   'remember',
#   'ticker',
#   'doctor',
#   'health',
#   'concern',
#   'discount',
#   'shortness',
#   'breath',
#   'palpitation',
#   'race',
#   'pulse',
#   'lightheadedness',
#   'symptom',
#   'large'],
#  ['literally',
#   'big',
#   'hater',
#   'working_clas',
#   'boot',
#   'licker',
#   'hack',
#   'establishment',
#   'desperate',
#   'twist',
#   'narrative',
#   'fool',
#   'tory',
#   'destruction',
#   'next',
#   'generalelection',
#   'soon'],
#  ['mind', 'explain', 'reason'],
#  ['omg', 'cool', 'fun', 'relatable', 'guy', 'wonder', 'check'],
#  ['action', 'master', 'amazing', 'hear'],
#  ['new_york'],
#  ['weird',
#   'conservative',
#   'regime',
#   'change',
#   'autocracy',
#   'dictatorship',
#   'actually',
#   'really'],
#  ['socialism',
#   'terrible',
#   'wrong',
#   'problem',
#   'conservative',
#   'well',
#   'problem',
#   'socialist',
#   'guy',
#   'real',
#   'monster',
#   'base',
#   'support',
#   'political',
#   'opinion',
#   'communism',
#   'socialism',
#   'fascism'],
#  ['day',
#   'evil',
#   'peaceful',
#   'protest',
#   'action',
#   'hold',
#   'new',
#   'york',
#   'grand',
#   'central',
#   'station',
#   'give',
#   'thumb',
#   'comrade',
#   'protest',
#   'scene',
#   'di'],
#  ['head', 'loose', 'owl', 'jfbbuyb'],
#  ['look',
#   'incredible',
#   'snap',
#   'post',
#   'kiss',
#   'songstress',
#   'accessorise',
#   'pair',
#   'gold',
#   'hoop',
#   'earring',
#   'wear',
#   'ipxbemkxm'],
#  ['inform', 'different', 'indoctrinated'],
#  ['wait',
#   'real',
#   'circus',
#   'yet',
#   'experience',
#   'enrichment',
#   'full',
#   'potential',
#   'vatorg'],
#  [],
#  ['music',
#   'scene',
#   'shamble',
#   'ice',
#   'spice',
#   'garbage',
#   'ass',
#   'lead',
#   'way'],
#  ['patriot', 'defend', 'thus', 'country', 'yet', 'shoot', 'damn', 'balloon'],
#  ['quick', 'visit', 'glasgow'],
#  ['pay', 'almost', 'watch', 'home', 'game', 'early', 'season'],
#  ['molly',
#   'sister',
#   'strapped',
#   'winter',
#   'gear',
#   'head',
#   'hunt',
#   'fossil',
#   'molly',
#   'collect',
#   'shark',
#   'tooth',
#   'latest',
#   'find',
#   'large',
#   'find',
#   'date'],
#  ['conservative',
#   'centrist',
#   'prove',
#   'biased',
#   'last',
#   'vote',
#   'bro',
#   'trash',
#   'corrupt',
#   'great',
#   'least',
#   'complete',
#   'joke'],
#  ['molly',
#   'sister',
#   'strapped',
#   'winter',
#   'gear',
#   'head',
#   'hunt',
#   'fossil',
#   'molly',
#   'collect',
#   'shark',
#   'tooth',
#   'latest',
#   'find',
#   'large',
#   'find',
#   'date'],
#  ['mayor', 'publicly', 'fair', 'yet', 'keep', 'place'],
#  ['accord',
#   'museum',
#   'molly',
#   'tooth',
#   'paleontology',
#   'department',
#   'access',
#   'marvel',
#   'discovery',
#   'anytime',
#   'lyiku'],
#  ['hillsborough',
#   'mp',
#   'public',
#   'advocate',
#   'bill',
#   'block',
#   'time',
#   'hvxai',
#   'vk'],
#  ['trump_likene', 'mob_boss', 'new', 'book'],
#  ['home', 'game', 'local', 'away', 'team', 'idea'],
#  ['ask', 'feb', 'convert', 'pen', 'city'],
#  ['random', 'fantasy', 'racing', 'pick', 'coliseum', 'nmiar', 'fnux'],
#  ['musk', 'tweet', 'debate', 'trial', 'near'],
#  ['spend',
#   'countless',
#   'hour',
#   'play',
#   'operation',
#   'course',
#   'lifetime',
#   'refer',
#   'surgeon',
#   'sell',
#   'surgery',
#   'bundle',
#   'march'],
#  ['perhaps', 'prefer'],
#  ['wrong',
#   'thread',
#   'amigo',
#   'monitor',
#   'english',
#   'language',
#   'proficiency',
#   'world',
#   'hope',
#   'money',
#   'back',
#   'alternatively',
#   'buy',
#   'special',
#   'unicorn',
#   'guy'],
#  ['brother',
#   'link',
#   'link',
#   'remember',
#   'famous',
#   'picture',
#   'connect',
#   'dot'],
#  ['evening', 'news'],
#  ['dictionary',
#   'definition',
#   'collaborate',
#   'verb',
#   'cooperate',
#   'treacherously',
#   'sound',
#   'exactly'],
#  ['thing', 'tell', 'snap', 'place', 'politician', 'trump', 'disarm'],
#  ['stream', 'watch', 'head', 'head', 'start', 'stadium', 'part', 'ngtb'],
#  ['one', 'tweets', 'safe', 'mate', 'knock'],
#  ['like', 'awov'],
#  ['money', 'global', 'company'],
#  ['shadow'],
#  ['pay', 'beyonce', 'vouch', 'spectacle', 'await'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['blast', 'attack', 'win', 'war', 'unthinkable'],
#  ['weep', 'chancer', 'anymore', 'disgraceful'],
#  ['weather', 'well', 'heavy', 'rain', 'wind', 'warm', 'yer', 'great', 'day'],
#  ['mesmerise', 'excited'],
#  ['break',
#   'match',
#   'wale',
#   'csm',
#   'united_kingdom',
#   'rd_february',
#   'ph',
#   'sixnation',
#   'sale'],
#  ['labour', 'cave', 'union', 'punish', 'mp', 'picket', 'show', 'solidarity'],
#  ['day',
#   'mychallenge',
#   'govt',
#   'last_year',
#   'meet',
#   'zoom',
#   'nearly',
#   'hrs',
#   'discuss',
#   'discrimination',
#   'deaf',
#   'swimmer',
#   'deal',
#   'confirm',
#   'money',
#   'support',
#   'deaf',
#   'swimmer',
#   'overtoyou'],
#  ['big',
#   'thing',
#   'travel',
#   'morning',
#   'ally',
#   'pally',
#   'area',
#   'probably',
#   'pm',
#   'meet',
#   'point'],
#  ['oh_dear', 'dear', 'guardian', 'damn', 'ant', 'someone', 'bang', 'door'],
#  ['remain', 'lido', 'waste'],
#  ['nearly',
#   'break',
#   'back',
#   'fall',
#   'step',
#   'feel',
#   'giblet',
#   'fall',
#   'hit',
#   'net',
#   'day'],
#  ['choose',
#   'point',
#   'far',
#   'time',
#   'suggest',
#   'entire',
#   'musical',
#   'genre',
#   'create',
#   'criminal',
#   'almost',
#   'offensive',
#   'handler',
#   'intend'],
#  ['modern',
#   'modern',
#   'car',
#   'year',
#   'mta',
#   'poorly',
#   'manage',
#   'complete',
#   'disaster',
#   'whole',
#   'system',
#   'rip',
#   'replace'],
#  ['pleasure',
#   'coach',
#   'loan',
#   'castleford',
#   'great',
#   'impact',
#   'outstanding',
#   'professional',
#   'still',
#   'league',
#   'hero',
#   'luck'],
#  ['mug', 'usually', 'mug', 'set', 'available', 'mufc'],
#  ['bad',
#   'tory',
#   'government',
#   'expect',
#   'care',
#   'much',
#   'afghan',
#   'friend',
#   'sure',
#   'prove',
#   'wrong',
#   'meet',
#   'ordinary',
#   'brit',
#   'work',
#   'tirelessly',
#   'save',
#   'amazing',
#   'volunteer'],
#  ['pay', 'pay'],
#  ['tomorrow', 'cloudy', 'high'],
#  ['rover', 'shock', 'charge', 'quid', 'ticket', 'shocking'],
#  ['night', 'bailey', 'wreck', 'night'],
#  ['fearful',
#   'troubled',
#   'heart',
#   'road',
#   'find',
#   'purpose',
#   'amp',
#   'motivation',
#   'video',
#   'link',
#   'th',
#   'author',
#   'ebookstore',
#   'ebooksale'],
#  ['much',
#   'electorate',
#   'vote',
#   'seat',
#   'majority',
#   'labour',
#   'block',
#   'real',
#   'democracy',
#   'minority',
#   'tory',
#   'continue',
#   'way'],
#  ['back',
#   'comment',
#   'conservative',
#   'past',
#   'long',
#   'ago',
#   'literally',
#   'put',
#   'people',
#   'jail',
#   'push',
#   'left',
#   'start',
#   'part',
#   'context',
#   'leave',
#   'far'],
#  ['look'],
#  ['leader', 'meet', 'live', 'update', 'trave'],
#  ['problem',
#   'arsenal',
#   'top',
#   'striker',
#   'play',
#   'position',
#   'striker',
#   'play',
#   'cf',
#   'brilliant',
#   'top',
#   'scorer',
#   'first',
#   'team',
#   'play',
#   'stupid',
#   'reason'],
#  ['way', 'minute', 'totp'],
#  ['basis', 'talk', 'alot', 'uk'],
#  ['already', 'brunch', 'tomorrow'],
#  ['order',
#   'pay',
#   'woman',
#   'fail',
#   'deal',
#   'infestation',
#   'flat',
#   'fourth',
#   'month'],
#  ['imagine'],
#  ['disreputable',
#   'journalist',
#   'actually',
#   'ask',
#   'question',
#   'least',
#   'credit',
#   'questioner',
#   'none',
#   'actually',
#   'athletic',
#   'new_york_time',
#   'well'],
#  ['day', 'boris'],
#  ['find', 'legend'],
#  ['transfer', 'update'],
#  ['great', 'working', 'initiative'],
#  ['still', 'believe'],
#  ['andrew_tate',
#   'influencer',
#   'threaten',
#   'worker',
#   'violence',
#   'victim',
#   'claim',
#   'hopefully',
#   'lie',
#   'fool',
#   'romanian',
#   'court',
#   'brother',
#   'give',
#   'lengthy',
#   'prison',
#   'sentence',
#   'pezutshq'],
#  ['clear',
#   'wind',
#   'gust',
#   'mph',
#   'pressure',
#   'mbar',
#   'rain_mm',
#   'index',
#   'weathercloud'],
#  ['approve',
#   'unsafe',
#   'school',
#   'classroom',
#   'claim',
#   'mask',
#   'work',
#   'allow',
#   'bcer',
#   'die',
#   'amp',
#   'wind',
#   'long',
#   'covid',
#   'due',
#   'cold',
#   'stubborness'],
#  ['nadine_dorrie', 'boris_johnson', 'friendship', 'unwavere', 'ally'],
#  [],
#  ['cure',
#   'disintegration',
#   'remastere',
#   'gram',
#   'vinyl',
#   'seal',
#   'vinyl',
#   'set'],
#  ['enjoy', 'interview', 'billgate'],
#  ['part', 'scotland', 'wholeheartedly'],
#  ['organize',
#   'gather',
#   'woman',
#   'anesthesiology',
#   'lecture',
#   'min',
#   'cooking',
#   'class',
#   'love',
#   'speaker',
#   'superwoman',
#   'let',
#   'connect'],
#  ['rest', 'day', 'mznacry'],
#  ['plastic_surgeon',
#   'madonna',
#   'madonna',
#   'ever',
#   'movie',
#   'plastic_surgeon',
#   'fam'],
#  ['edition',
#   'sixnation',
#   'kick',
#   'tomorrow',
#   'travel',
#   'principality',
#   'stadium',
#   'wale',
#   'gatland',
#   'first',
#   'game',
#   'charge',
#   'return',
#   'head',
#   'coach',
#   'turn',
#   'prediction',
#   'pound',
#   'exrzjtyste'],
#  ['film', 'street', 'new_york'],
#  ['dundee',
#   'councillor',
#   'seek',
#   'agreement',
#   'support',
#   'ban',
#   'disposable',
#   'vape'],
#  ['lone', 'female', 'dog', 'walker', 'attack'],
#  ['boris_johnson', 'tell', 'talk', 'paint', 'cow', 'ftwbdj'],
#  ['favour', 'guarantee', 'penalty', 'scotland'],
#  ['labour',
#   'fund',
#   'union',
#   'tory',
#   'fund',
#   'millionaire',
#   'amp',
#   'corporation',
#   'return',
#   'favour',
#   'always',
#   'thus'],
#  ['hammer', 'kickoff', 'second', 'half'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['point', 'english', 'manager', 'bother'],
#  ['poison',
#   'host',
#   'kill',
#   'cancer',
#   'labour',
#   'case',
#   'starve',
#   'member',
#   'fee',
#   'volunteer',
#   'work',
#   'voter',
#   'far',
#   'parasite',
#   'long',
#   'sustain'],
#  ['jog',
#   'memory',
#   'back',
#   'day',
#   'social',
#   'study',
#   'curriculum',
#   'definitely',
#   'overlook',
#   'much',
#   'history',
#   'kanienkehaka',
#   'mohawk',
#   'people',
#   'wish',
#   'karonienhawe',
#   'diabo',
#   'great',
#   'show',
#   'co'],
#  ['old',
#   'beverage',
#   'entrepreneur',
#   'buy',
#   'football',
#   'club',
#   'actually',
#   'laidi'],
#  ['promise', 'perch'],
#  ['bit', 'inaction', 'man'],
#  ['serve',
#   'elongate',
#   'career',
#   'referee',
#   'implementation',
#   'remit',
#   'reduce',
#   'remove',
#   'affect',
#   'subjective',
#   'decision'],
#  ['maybe', 'ask', 'exact', 'policy', 'year'],
#  ['mistakenly', 'place', 'sign', 'footpath', 'back', 'belong'],
#  ['oddly',
#   'idea',
#   'food',
#   'chinese',
#   'restaurant',
#   'allegedly',
#   'cause',
#   'foot',
#   'mouth',
#   'pig',
#   'feed',
#   'uj'],
#  ['motherwell'],
#  ['climate_change',
#   'real',
#   'problem',
#   'claim',
#   'earth',
#   'uninhabitable',
#   'soon',
#   'accurately',
#   'represent',
#   'current',
#   'state',
#   'scientific',
#   'knowledge',
#   'detail',
#   'matter',
#   'serious',
#   'problem',
#   'overstate',
#   'ut'],
#  ['evil',
#   'die',
#   'industry',
#   'linger',
#   'government',
#   'taxpayer',
#   'dollar',
#   'nearly',
#   'percent',
#   'taxpayer',
#   'long',
#   'support',
#   'dog',
#   'racing',
#   'subsidize',
#   'archaic',
#   'blood',
#   'sport',
#   'vote',
#   'voice',
#   'pay',
#   'cruelty'],
#  ['skoda',
#   'motorsport',
#   'shirt',
#   'tune',
#   'personalise',
#   'gift',
#   'sport',
#   'travel',
#   'adventure',
#   'cadeau_sport',
#   'fashion',
#   'https'],
#  ['still',
#   'sen',
#   'avoid',
#   'rental',
#   'player',
#   'list',
#   'term',
#   'interested',
#   'panther',
#   'forward',
#   'return'],
#  ['often',
#   'wonder',
#   'explore',
#   'much',
#   'wale',
#   'great',
#   'train',
#   'network',
#   'look',
#   'book',
#   'trip',
#   'harlech',
#   'discover',
#   'cheap',
#   'https'],
#  ['comedian', 'brilliant', 'tragic'],
#  ['speak',
#   'man',
#   'fail',
#   'imo',
#   'huge',
#   'emphasis',
#   'back',
#   'well',
#   'start',
#   'flare',
#   'tic'],
#  ['debut', 'tonight', 'eqvryfjtpm'],
#  ['sell', 'coldplay', 'ticket', 'interested'],
#  ['hospital',
#   'workplace',
#   'cool',
#   'light',
#   'temperature',
#   'usually',
#   'keep',
#   'brain',
#   'stimulate',
#   'awake',
#   'explain',
#   'senior',
#   'lighting',
#   'designer'],
#  ['student',
#   'full',
#   'cold',
#   'sore',
#   'throat',
#   'sure',
#   'rest',
#   'well',
#   'weekend'],
#  ['explain',
#   'detail',
#   'already',
#   'pay',
#   'profit',
#   'rest',
#   'country',
#   'tax',
#   'extra',
#   'money',
#   'much',
#   'money'],
#  ['twerp',
#   'uppity',
#   'tory',
#   'give',
#   'justify',
#   'mouthful',
#   'shit',
#   'pant',
#   'joy',
#   'reverse'],
#  ['stop',
#   'transplant',
#   'tran',
#   'woman',
#   'likely',
#   'future',
#   'claim',
#   'top',
#   'fertility',
#   'expert',
#   'world',
#   'first',
#   'op',
#   'carry'],
#  ['thing',
#   'stupid',
#   'look',
#   'hornet',
#   'last',
#   'year',
#   'look',
#   'look',
#   'give',
#   'timofey',
#   'mozgov',
#   'insane',
#   'contract'],
#  ['edutwitter',
#   'folk',
#   'tempt',
#   'limited',
#   'edition',
#   'shirt',
#   'celebrate',
#   'original',
#   'educational',
#   'disruptor',
#   'social',
#   'pioneer',
#   'pysxpqm',
#   'tc'],
#  ['much', 'money', 'millionaire', 'big', 'business', 'give', 'tory', 'deal'],
#  ['corrie'],
#  ['enjoy', 'gig', 'pal', 'last', 'week', 'wow'],
#  ['ask',
#   'people',
#   'scotland',
#   'decide',
#   'demote',
#   'second',
#   'class',
#   'citizen',
#   'give',
#   'scared'],
#  ['introduce', 'little', 'people', 'retro', 'comedy', 'uncle', 'buck'],
#  ['support', 'tyrone', 'senior', 'hurler', 'tomorrow', 'night'],
#  ['dog', 'dinner', 'scotland'],
#  ['bruh',
#   'stfu',
#   'business',
#   'fucking',
#   'twitter',
#   'facebook',
#   'new_york_time',
#   'ton',
#   'business',
#   'small',
#   'meaning',
#   'less',
#   'income',
#   'due',
#   'small',
#   'less',
#   'less',
#   'advertising',
#   'less',
#   'customer',
#   'less',
#   'employee',
#   'less',
#   'income'],
#  ['live'],
#  ['sell', 'blackpink', 'ticket'],
#  ['imagine',
#   'club',
#   'slo',
#   'put',
#   'thing',
#   'place',
#   'help',
#   'stadium',
#   'bad',
#   'seat',
#   'worth',
#   'phone',
#   'call'],
#  ['top', 'moment', 'twitter', 'history'],
#  ['teacher',
#   'appreciation',
#   'roundup',
#   'favourite',
#   'fictional',
#   'teacher',
#   'fvkq',
#   'snif'],
#  ['long',
#   'already',
#   'work',
#   'huge',
#   'new',
#   'tv',
#   'series',
#   'today',
#   'send',
#   'absolutely',
#   'brilliant',
#   'self',
#   'tape',
#   'scottish',
#   'feature',
#   'film',
#   'self',
#   'tape',
#   'request',
#   'straight',
#   'scottish',
#   'film',
#   'excited',
#   'glasgow',
#   'actor'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['cardiff',
#   'pushover',
#   'player',
#   'brain',
#   'explosion',
#   'probably',
#   'bad',
#   'team'],
#  ['elect', 'dictatorship'],
#  ['play',
#   'stay',
#   'listen',
#   'online',
#   'emergingartist',
#   'music',
#   'newmusic',
#   'unsigned',
#   'independent',
#   'emerge',
#   'radio',
#   'playlist',
#   'nowplaying'],
#  ['switzerland'],
#  ['never', 'manage', 'find', 'list'],
#  ['follow', 'page', 'break', 'shamble'],
#  ['away',
#   'holiday',
#   'birthday',
#   'super',
#   'deal',
#   'ohuaxbgwse',
#   'well',
#   'beautiful',
#   'pic',
#   'sexy',
#   'red',
#   'underwear',
#   'video',
#   'cumme',
#   'next',
#   'week',
#   'uj'],
#  ['speak',
#   'war',
#   'ukraine',
#   'convenient',
#   'place',
#   'country',
#   'bio',
#   'weapon',
#   'money',
#   'launder',
#   'feel',
#   'ukrainian',
#   'help',
#   'protect',
#   'asset',
#   'innocent',
#   'ukrainian'],
#  ['empty', 'wine', 'box', 'build', 'bus'],
#  ['reporter',
#   'daily',
#   'beast',
#   'highlight',
#   'role',
#   'medium',
#   'brand',
#   'romanian',
#   'political',
#   'party',
#   'payment',
#   'scandal',
#   'https'],
#  ['tran', 'activist', 'crash', 'woman', 'demo', 'dress', 'cat', 'dog'],
#  ['much', 'mortgage', 'hint', 'kwasis', 'boss'],
#  ['horse_race', 'tip', 'remastere', 'yubr'],
#  ['retweet',
#   'newly',
#   'release',
#   'convict',
#   'pedophile',
#   'photo',
#   'turn',
#   'somewhere',
#   'glitter'],
#  ['much', 'lebedev'],
#  ['player', 'neg', 'map', 'shock', 'performance'],
#  ['blueprint',
#   'ceo',
#   'robyn',
#   'beaver',
#   'speak',
#   'year',
#   'new_york',
#   'schedule',
#   'pack',
#   'industry',
#   'lead',
#   'content',
#   'full',
#   'https',
#   'realestate',
#   'cleanenergy',
#   'decarbonization'],
#  ['war',
#   'monger',
#   'globalist',
#   'clown',
#   'commit',
#   'grand',
#   'treason',
#   'wake',
#   'people'],
#  ['leave', 'tonbridge', 'morning', 'co', 'yzeitr'],
#  ['today', 'annual', 'general', 'meeting', 'elect', 'uxmo'],
#  ['remember', 'fish', 'tank', 'outside', 'choose', 'fish', 'course', 'dinner'],
#  ['fabulous', 'asset', 'team'],
#  [],
#  ['love', 'show', 'love', 'learn'],
#  ['airline',
#   'already',
#   'dollar',
#   'card',
#   'pay',
#   'needful',
#   'strength',
#   'drama'],
#  ['head', 'hurt', 'fibro'],
#  ['amazing',
#   'word',
#   'warrior',
#   'grandmother',
#   'give',
#   'kinship',
#   'carer',
#   'voice'],
#  ['shadow'],
#  ['woman',
#   'kill',
#   'service',
#   'insensitive',
#   'victim',
#   'family',
#   'give',
#   'speech',
#   'people',
#   'describe',
#   'terror',
#   'attack',
#   'waa'],
#  ['dude', 'prime_minister', 'anymore'],
#  ['miss', 'woman', 'let', 'hope', 'find', 'safe', 'ltsdrxnyjk'],
#  ['reopen', 'connected'],
#  ['tantrum', 'tantrum', 'crocodile', 'episode'],
#  ['people',
#   'admit',
#   'corbyn',
#   'win',
#   'nonce',
#   'mate',
#   'work',
#   'everyday',
#   'several',
#   'ex',
#   'blairite',
#   'employ',
#   'twitter',
#   'disagree',
#   'wake'],
#  ['live', 'marble', 'rally', 'truly', 'epitome', 'marble', 'racing'],
#  ['wale',
#   'ready',
#   'spend',
#   'couple',
#   'day',
#   'wale',
#   'camp',
#   'week',
#   'rare',
#   'scene',
#   'access',
#   'new',
#   'zealander',
#   'never',
#   'away',
#   'walvire',
#   'sixnation'],
#  ['time'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['rest', 'pay_rise', 'greedy'],
#  ['work', 'look'],
#  ['award_wine',
#   'poet',
#   'legal',
#   'scholar',
#   'visionary',
#   'perform',
#   'original',
#   'spoken',
#   'word',
#   'title',
#   'unanswered'],
#  ['call', 'police', 'girl', 'catch', 'lanternflie', 'honor'],
#  ['true', 'refugee', 'complain'],
#  ['midday', 'single', 'saturday', 'door', 'open'],
#  ['bad', 'thing'],
#  ['corrupt', 'labour'],
#  ['image', 'shirt', 'site', 'sand', 'colour', 'cheer'],
#  ['mkq',
#   'zwrt',
#   'less',
#   'half',
#   'give',
#   'tory',
#   'party',
#   'wonder',
#   'expect',
#   'return'],
#  ['continue',
#   'play',
#   'well',
#   'neglect',
#   'mention',
#   'fine',
#   'stop',
#   'prior',
#   'opener',
#   'htg'],
#  ['jaswant',
#   'chail',
#   'turn',
#   'windsor',
#   'armed',
#   'load',
#   'crossbow',
#   'day',
#   'announce',
#   'queen',
#   'experience',
#   'psychotic',
#   'episode',
#   'time'],
#  ['dought', 'bud', 'labour', 'protect'],
#  ['lovely', 'send', 'enormous', 'snack', 'irn'],
#  ['somewhere',
#   'new_york_city',
#   'blind',
#   'woman',
#   'work',
#   'massage',
#   'idea',
#   'dee',
#   'place'],
#  ['sub', 'pay', 'drink', 'tonight'],
#  ['conservative',
#   'never',
#   'support',
#   'sort',
#   'law',
#   'whole',
#   'point',
#   'private',
#   'school',
#   'able',
#   'control'],
#  ['require',
#   'brake',
#   'feel',
#   'alot',
#   'foot',
#   'stamp',
#   'hard',
#   'retarder',
#   'really',
#   'work',
#   'well',
#   'steer',
#   'light'],
#  ['lazy', 'greedy', 'self', 'indulgent', 'conservative', 'uotcxpoavw'],
#  ['accident', 'report', 'icdzq'],
#  ['rare',
#   'piece',
#   'video',
#   'former',
#   'president',
#   'oath',
#   'never',
#   'footage',
#   'https'],
#  ['commercial', 'sale', 'ask', 'price', 'https', 'vizn', 'qvhi'],
#  ['pale', 'blue', 'eye', 'pale', 'blue', 'eye', 'hxdk'],
#  ['fight', 'democracy', 'accountable', 'medium'],
#  ['quick', 'mutual', 'suck', 'liverpool', 'dm'],
#  ['lose',
#   'seat',
#   'therefore',
#   'power',
#   'fact',
#   'party',
#   'adopt',
#   'transgender',
#   'ideology',
#   'lose',
#   'vote',
#   'believe',
#   'child',
#   'allow',
#   'grow',
#   'adulthood',
#   'put',
#   'risk'],
#  ['spur',
#   'money',
#   'cash',
#   'strapped',
#   'government',
#   'offer',
#   'sponsorship',
#   'free',
#   'money',
#   'show',
#   'increase',
#   'income',
#   'sort',
#   'social',
#   'investment',
#   'agreement',
#   'sense',
#   'morally',
#   'suspect',
#   'puiirm'],
#  ['first',
#   'crash',
#   'almost',
#   'year',
#   'survive',
#   'tell',
#   'ankle',
#   'fuck',
#   'lovely',
#   'scooter',
#   'rider',
#   'move',
#   'bike',
#   'main',
#   'road',
#   'faith',
#   'humanity',
#   'restore',
#   'beer',
#   'cocktail',
#   'painkiller'],
#  ['sell', 'stand', 'feb_th', 'look', 'lmk', 'interested'],
#  ['true', 'watch', 'labour', 'file'],
#  ['random', 'fantasy', 'racing', 'pick', 'coliseum'],
#  ['color',
#   'rich',
#   'trait',
#   'bloodthirsty',
#   'open',
#   'book',
#   'anger',
#   'disappear',
#   'hoblwrtb'],
#  ['petition'],
#  ['crack', 'show', 'today', 'kinda', 'describe', 'perversion'],
#  ['sell',
#   'beyonce',
#   'tour',
#   'priority',
#   'standing_ticket',
#   'pm',
#   'sell',
#   'face_value',
#   'beyonceticket',
#   'beyonce'],
#  ['film', 'street', 'new_york'],
# ...
#   'police_officer',
#   'cop',
#   'cop',
#   'today',
#   'pendulum',
#   'swing',
#   'back',
#   'current',
#   'brokenness',
#   'embarrass'],
#  ['language',
#   'language',
#   'island',
#   'separate',
#   'water',
#   'water',
#   'earth',
#   'moreover',
#   'continent',
#   'meaning'],
#  ['still', 'mean', 'conservative', 'word', 'throw', 'anywhere', 'like'],
#  ['literally', 'sit', 'eat', 'lunch', 'coach', 'perfect'],
#  ['parallel', 'universe', 'utter', 'bollock'],
#  ['perhaps',
#   'chief',
#   'constable',
#   'first',
#   'advise',
#   'concern',
#   'knife',
#   'crime'],
#  ['city'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['visit',
#   'housman',
#   'tomorrow',
#   'sell',
#   'inspire',
#   'work',
#   'former',
#   'mp',
#   'joan',
#   'lovely',
#   'amp',
#   'kind',
#   'woman',
#   'unswerve',
#   'principle',
#   'join',
#   'tomorrow',
#   'celebrate',
#   'tyl'],
#  ['safety',
#   'report',
#   'toxicology',
#   'recommend',
#   'pregnancy',
#   'breastfeed',
#   'manufacturer',
#   'stop',
#   'harm',
#   'mother',
#   'baby',
#   'official',
#   'government',
#   'document',
#   'toxicology',
#   'cf'],
#  ['love', 'kind', 'generous', 'sure', 'sure', 'fancy'],
#  ['check', 'scenecap', 'video', 'tiktok', 'https', 'co', 'ptcmmxx'],
#  ['mouth', 'watering', 'sight'],
#  ['trip', 'tonight', 'first', 'visit', 'bkirol'],
#  ['worry', 'already', 'bad', 'cost', 'living', 'crisis', 'strike'],
#  ['refuse', 'fb'],
#  ['hi_im_develope', 'free', 'video', 'profile'],
#  ['couple', 'knock', 'ok', 'nowt', 'serious'],
#  ['scrutinise', 'bill', 'scotland', 'history', 'unravel', 'quickly'],
#  ['never',
#   'wrong',
#   'welcome',
#   'immigrant',
#   'open',
#   'arm',
#   'pay',
#   'reparation',
#   'mean',
#   'immigrant',
#   'completely',
#   'understandable'],
#  ['fall', 'government', 'sack'],
#  ['gutter', 'creep', 'charge'],
#  ['stop', 'live', 'whore'],
#  ['likely', 'always', 'greatest', 'decorate', 'athlete', 'new_york'],
#  ['embattle', 'hit', 'explosive', 'claim', 'tell', 'apart'],
#  ['objectively', 'glow', 'dark', 'new_york', 'back', 'always', 'eye'],
#  ['former', 'director'],
#  ['manager', 'assistant'],
#  ['schedule', 'update', 'release'],
#  ['heart', 'race', 'vacation', 'focus', 'baby'],
#  ['support', 'striker'],
#  ['remember', 'almaz', 'night', 'flite', 'compilation', 'bed', 'song', 'totp'],
#  ['exactly', 'feel', 'watch', 'play'],
#  ['social_media',
#   'search',
#   'engine',
#   'always',
#   'point',
#   'finger',
#   'foreign',
#   'country',
#   'ignore',
#   'far',
#   'big',
#   'issue',
#   'conservative',
#   'current',
#   'situation',
#   'far',
#   'rule',
#   'class'],
#  ['government', 'cash', 'shower', 'never', 'fault', 'tory', 'guess', 'blame'],
#  ['great', 'support', 'vhohw', 'fi'],
#  ['itx', 'gaming', 'graphic', 'card', 'instock'],
#  ['case',
#   'dismiss',
#   'limerick',
#   'man',
#   'man',
#   'name',
#   'halting',
#   'site',
#   'qlakpqymi'],
#  ['wolve', 'new_york_city', 'help', 'city', 'realm'],
#  ['tether',
#   'likely',
#   'especially',
#   'open',
#   'world',
#   'game',
#   'upto',
#   'player',
#   'speculation',
#   'surprised',
#   'pop',
#   'friend',
#   'world',
#   'server',
#   'base',
#   'way',
#   'reason',
#   'online',
#   'connection'],
#  ['race', 'weekend', 'hope', 'day'],
#  ['read',
#   'maybe',
#   'big',
#   'part',
#   'father',
#   'read',
#   'aloud',
#   'year',
#   'reason',
#   'ongoing',
#   'explosion',
#   'audio',
#   'really',
#   'actually',
#   'fun',
#   'yyf'],
#  ['nf', 'exedy', 'nf', 'chromoly', 'racing'],
#  ['new',
#   'castle',
#   'anytime',
#   'soon',
#   'city',
#   'basis',
#   'peace',
#   'enjoy',
#   'delude'],
#  ['snowdrop'],
#  ['wooden', 'spoon', 'face', 'draw', 'child', 'interview', 'talktv'],
#  ['woman', 'trefoil', 'mule', 'clutch', 'bag', 'new', 'size', 'rjthvqztt'],
#  ['race', 'footrest', 'rearset', 'rear', 'set', 'foot', 'peg'],
#  ['durable',
#   'constant',
#   'eternal',
#   'chance',
#   'social',
#   'condition',
#   'human',
#   'nature',
#   'brain',
#   'suppose',
#   'survival',
#   'much',
#   'long',
#   'sure'],
#  ['win',
#   'actually',
#   'conservative',
#   'dress',
#   'presidential',
#   'candidate',
#   'moderate',
#   'centrist',
#   'win',
#   'dem',
#   'drag',
#   'win'],
#  ['match', 'pass', 'tomorrow', 'game', 'available', 'lymnxtq'],
#  ['mason_greenwood', 'remain'],
#  ['rider', 'motorcycle', 'personalise', 'gift', 'cadeau_sport', 'fashion'],
#  ['rear', 'video', 'sport', 'sportingcp'],
#  ['underestimate', 'useless', 'moye', 'really'],
#  ['fancy', 'playing', 'mot', 'roulette', 'pass'],
#  ['maybe',
#   'dad',
#   'live',
#   'new',
#   'self',
#   'employ',
#   'life',
#   'abstract',
#   'shirt',
#   'birkenstock',
#   'boston',
#   'thick',
#   'sock',
#   'drive',
#   'safe',
#   'time'],
#  ['petition'],
#  ['trump',
#   'maga',
#   'policy',
#   'back',
#   'low',
#   'taxis',
#   'cheap',
#   'low',
#   'energy',
#   'cost',
#   'liberal',
#   'green',
#   'steel',
#   'money',
#   'rich',
#   'agenda',
#   'already',
#   'increase',
#   'taxis',
#   'american',
#   'economy'],
#  ['depress',
#   'cold',
#   'gloomy',
#   'northern',
#   'winter',
#   'struggle',
#   'sky',
#   'often',
#   'enough'],
#  ['mp',
#   'bank',
#   'offshore',
#   'taxpayer',
#   'money',
#   'tory',
#   'torycriminal',
#   'sunakout'],
#  ['prime_minister', 'release', 'fourth', 'batch', 'cabinet', 'report', 'view'],
#  ['man', 'work', 'rate', 'study'],
#  ['agree',
#   'policy',
#   'initiative',
#   'bad',
#   'thing',
#   'conservative',
#   'divide',
#   'support'],
#  ['million',
#   'donate',
#   'tory',
#   'ensure',
#   'nhs',
#   'sell',
#   'peanut',
#   'profiteering',
#   'insurance',
#   'company'],
#  ['state',
#   'cke',
#   'idiot',
#   'return',
#   'primary',
#   'school',
#   'miss',
#   'understand',
#   'big',
#   'picture',
#   'print',
#   'opinion',
#   'obviously',
#   'simple',
#   'understand'],
#  ['devout', 'claim', 'force', 'hh'],
#  ['beg', 'allow', 'fight', 'next_election', 'labour', 'bfxpkj'],
#  ['stress', 'bro', 'none', 'signing', 'start', 'trust'],
#  ['gas', 'meter', 'fit', 'force', 'political', 'cartoon'],
#  ['fire', 'else', 'day', 'official', 'long', 'capable', 'regardless', 'issue'],
#  ['wonderful',
#   'man',
#   'extremely',
#   'kind',
#   'amp',
#   'care',
#   'physician',
#   'excellent',
#   'surgeon',
#   'love',
#   'work',
#   'greatly',
#   'miss',
#   'rest',
#   'peace'],
#  ['early', 'gig', 'rd', 'bed'],
#  ['true',
#   'one',
#   'social',
#   'security',
#   'medicare',
#   'people',
#   'enslave',
#   'government',
#   'conservative',
#   'people',
#   'become',
#   'self',
#   'reliant'],
#  ['find', 'recently', 'almost', 'big', 'england', 'sea', 'reckon', 'surf'],
#  ['oof', 'radiology', 'work', 'radwoman', 'radleader', 'radequal'],
#  ['bond',
#   'baby',
#   'daddy',
#   'relationship',
#   'gang',
#   'banger',
#   'date',
#   'life',
#   'difference',
#   'pretty',
#   'actually',
#   'flip',
#   'tax',
#   'money'],
#  ['fuck', 'cost', 'living', 'fucking', 'pay', 'https', 'co', 'czbbekrh'],
#  ['exit', 'ug'],
#  ['racing', 'field', 'full', 'time', 'entry', 'crew', 'chief', 'ikjpfhzjwk'],
#  ['stop',
#   'post',
#   'anti',
#   'tran',
#   'hate',
#   'speech',
#   'disguise',
#   'journalism',
#   'feminism'],
#  ['mom', 'involve', 'car', 'crash', 'los_angeles', 'new_york', 'trave'],
#  ['omo', 'pound', 'worth', 'man', 'presidential', 'project', 'slogan'],
#  ['sale', 'thread', 'buy', 'stuff'],
#  ['exclusive',
#   'new_york_time',
#   'wait',
#   'day',
#   'report',
#   'authenticated',
#   'hunter',
#   'biden',
#   'laptop',
#   'email',
#   'https'],
#  ['wish',
#   'big',
#   'enough',
#   'cork',
#   'fit',
#   'mouth',
#   'exhaust',
#   'listen',
#   'stupid',
#   'day',
#   'long'],
#  ['thing', 'state', 'law', 'allow', 'waste', 'time'],
#  ['start'],
#  ['wish', 'perform'],
#  ['earn', 'medical', 'degree', 'educate', 'admit', 'lxbhfwtv'],
#  ['never',
#   'understand',
#   'surely',
#   'person',
#   'job',
#   'matter',
#   'colour',
#   'skin'],
#  ['pediatric',
#   'surgeon',
#   'sentence',
#   'prison',
#   'possession',
#   'distribution',
#   'child',
#   'pornography'],
#  ['move', 'suddenly', 'yorkshire', 'bad'],
#  ['head', 'delegation', 'drag', 'shitter', 'irish', 'ff'],
#  [],
#  ['new', 'marcus', 'rashford', 'name', 'team', 'beat', 'season', 'sky'],
#  ['gentleman',
#   'happen',
#   'back',
#   'motherland',
#   'wale',
#   'moment',
#   'add',
#   'research',
#   'list'],
#  ['great', 'work', 'fly', 'guy'],
#  ['time',
#   'answer',
#   'leave',
#   'back',
#   'control',
#   'sovereign',
#   'country',
#   'vassal',
#   'frozen',
#   'threat',
#   'violence'],
#  ['small',
#   'handful',
#   'people',
#   'tell',
#   'miss',
#   'tv',
#   'suspiciously',
#   'always',
#   'else',
#   'around',
#   'verify',
#   'tonight',
#   'lucky',
#   'night'],
#  ['wonder', 'still'],
#  ['feral',
#   'pig',
#   'mom',
#   'baby',
#   'time',
#   'fantastic',
#   'half',
#   'badly',
#   'shoot',
#   'leave',
#   'bleed'],
#  ['final', 'app'],
#  ['olly', 'show', 'moment', 'post', 'gig', 'depression', 'today', 'book'],
#  ['true',
#   'multiple',
#   'level',
#   'vaccine',
#   'prevent',
#   'spread',
#   'covid',
#   'city',
#   'new_york',
#   'play',
#   'game'],
#  ['wear', 'bed', 'alone'],
#  ['weekend', 'play', 'new', 'groovy', 'teambrisk', 'fan', 'world'],
#  ['death', 'much', 'global', 'warming', 'yet', 'morte', 'global', 'dando'],
#  ['conservative',
#   'sacred',
#   'ballon',
#   'time',
#   'grow',
#   'ball',
#   'well',
#   'stay',
#   'away',
#   'kid',
#   'party'],
#  ['red', 'state', 'thing'],
#  ['sabi'],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['posted_photo', 'garden', 'city', 'ob'],
#  ['sbq'],
#  ['motorsport',
#   'well',
#   'cycle',
#   'race',
#   'horse_race',
#   'football',
#   'archive',
#   'negative',
#   'rescue',
#   'italian'],
#  ['explain', 'food'],
#  ['save', 'shoot'],
#  ['hope'],
#  ['old', 'orchard', 'old', 'orchard', 'beach', 'apggydugiww'],
#  ['horse', 'co'],
#  ['patriot',
#   'icon',
#   'ugly',
#   'pajama',
#   'set',
#   'price',
#   'buy',
#   'kongknsxoq',
#   'patriot',
#   'pajama',
#   'set',
#   'cute',
#   'comfortable',
#   'size',
#   'whole',
#   'family',
#   'patriot',
#   'uglypajamaset',
#   'dbybehq'],
#  ['hope',
#   'horse_race',
#   'warm',
#   'moment',
#   'rush',
#   'story',
#   'scene',
#   'contain',
#   'romance',
#   'actually',
#   'confess',
#   'love',
#   'consider',
#   'way',
#   'partner'],
#  ['finally', 'record', 'disneyworld', 'podcast'],
#  ['hem', 'track', 'worth'],
#  ['teacher', 'far', 'low', 'standard', 'touch', 'turn'],
#  ['nature', 'place', 'mean', 'enter', 'competition', 'chance', 'win', 'haezl'],
#  ['deep',
#   'snowpack',
#   'southern',
#   'temperature',
#   'tonight',
#   'potentially',
#   'shatter',
#   'record'],
#  ['cov', 'game', 'sky', 'sport', 'app', 'app', 'struggle', 'uvdr'],
#  ['file',
#   'clark',
#   'cv',
#   'category',
#   'product',
#   'liability',
#   'asbestos',
#   'toxic',
#   'environmental',
#   'type',
#   'unlimited',
#   'civil'],
#  ['petition'],
#  ['wear',
#   'sort',
#   'sure',
#   'sturgeon',
#   'wear',
#   'similar',
#   'denote',
#   'rank',
#   'way',
#   'perhaps',
#   'fail',
#   'mention',
#   'scot',
#   'vote',
#   'selective',
#   'memory',
#   'snp'],
#  ['tie',
#   'bbcaq',
#   'sturgeon',
#   'gender',
#   'petition',
#   'ask',
#   'parliament',
#   'update',
#   'equality',
#   'act',
#   'clear',
#   'characteristic',
#   'sex',
#   'biological',
#   'sex',
#   'wale',
#   'scotland',
#   'vyrjuoozz'],
#  ['threat', 'resist', 'palestinian', 'support'],
#  ['dog',
#   'tax',
#   'illigal',
#   'party',
#   'reverse',
#   'ni',
#   'hike',
#   'pay',
#   'well',
#   'social',
#   'care',
#   'help',
#   'nhs',
#   'tanking',
#   'economy',
#   'raise',
#   'energy',
#   'price',
#   'high',
#   'choose',
#   'food',
#   'heat'],
#  ['key',
#   'word',
#   'note',
#   'terrible',
#   'response',
#   'vogue',
#   'victimhood',
#   'career',
#   'edit',
#   'stoic',
#   'sound',
#   'edit'],
#  ['omg', 'imagine'],
#  ['hypothetically', 'plan'],
#  ['sue', 'school', 'son', 'participate'],
#  ['film', 'street', 'new_york'],
#  ['give', 'colleague', 'wake', 'specifically', 'mayor'],
#  ['police', 'miss', 'dog', 'walker', 'fall'],
#  ['time', 'leftie', 'zealot'],
#  ['radical', 'crime'],
#  ['still',
#   'playground',
#   'campground',
#   'facility',
#   'concern',
#   'ballon',
#   'spy',
#   'hxtbe',
#   'wwx'],
#  ['insanely', 'cheap', 'costco'],
#  ['ever',
#   'fancy',
#   'watch',
#   'film',
#   'mentality',
#   'scar',
#   'rest',
#   'natural',
#   'heartily',
#   'recommend',
#   'thread',
#   'film',
#   'mid',
#   'matter',
#   'nuclear',
#   'war',
#   'ensue',
#   'aftermath',
#   'truly',
#   'harrowing',
#   'view'],
#  ['become',
#   'train',
#   'clean',
#   'sadly',
#   'low',
#   'wage',
#   'lead',
#   'food',
#   'bank',
#   'free',
#   'travel',
#   'yay',
#   'guess'],
#  ['community',
#   'new',
#   'hadleigh',
#   'pub',
#   'landlord',
#   'team',
#   'put',
#   'lovely',
#   'community',
#   'profit'],
#  ['realtor',
#   'mark',
#   'low',
#   'number',
#   'home',
#   'sale',
#   'first',
#   'month',
#   'year',
#   'agjyoqi'],
#  ['beautiful',
#   'people',
#   'hate',
#   'tory',
#   'system',
#   'electoral',
#   'reform',
#   'give',
#   'follow',
#   'artwork'],
#  ['instead', 'laugh'],
#  ['huge',
#   'majority',
#   'overturn',
#   'personally',
#   'hope',
#   'win',
#   'bother',
#   'vote'],
#  ['buy',
#   'phone',
#   'ship',
#   'air',
#   'tight',
#   'seal',
#   'container',
#   'pandemic',
#   'world',
#   'deadly',
#   'virus',
#   'shoot',
#   'chinaballoon',
#   'balloon'],
#  ['finally', 'shudder', 'watch', 'soon', 'hehe'],
#  ['connect',
#   'heavy',
#   'rail',
#   'light',
#   'rail',
#   'awful',
#   'car',
#   'road',
#   'town',
#   'bring',
#   'gluas',
#   'wdr',
#   'extension',
#   'barna',
#   'reduce',
#   'car',
#   'west',
#   'side'],
#  ['operation', 'well'],
#  ['check',
#   'top',
#   'profile',
#   'patently',
#   'parody',
#   'second',
#   'embarrasse',
#   'people',
#   'end',
#   'world',
#   'blush',
#   'lighten'],
#  ['absolute',
#   'awe',
#   'superior',
#   'intellect',
#   'admit',
#   'hatred',
#   'patriotism',
#   'apply'],
#  ['fantastic', 'work', 'look', 'plan', 'sequence', 'energy', 'system'],
#  ['conservative', 'reflexive', 'opposition', 'tend', 'wrong', 'side'],
#  ['rgdc'],
#  ['spring'],
#  ['inspire', 'story', 'talk', 'th', 'former', 'buckinghamshire', 'love'],
#  ['well', 'money', 'union', 'fund', 'worker', 'oligarch', 'grip'],
#  ['black',
#   'cab',
#   'driver',
#   'year',
#   'average',
#   'pass',
#   'knowledge',
#   'represent',
#   'certain',
#   'level',
#   'safety',
#   'security',
#   'high',
#   'standard',
#   'synonymous',
#   'thing',
#   'certainly',
#   'pay'],
#  ['finally', 'find', 'water', 'exciting', 'period', 'conservative', 'live'],
#  ['conservative', 'shoot'],
#  [],
#  ['instead',
#   'worker',
#   'corner',
#   'india_asia_etc',
#   'let_eu',
#   'worker',
#   'similar_culture',
#   'labour_shortage'],
#  ['wither',
#   'push',
#   'back',
#   'week',
#   'weather',
#   'forecast',
#   'promise',
#   'dangerous',
#   'sub',
#   'wind',
#   'chill'],
#  ['wonky',
#   'appear',
#   'anyway',
#   'wonky',
#   'real',
#   'person',
#   'jack',
#   'fake',
#   'definitely',
#   'obvious',
#   'tone',
#   'behaviour',
#   'weird',
#   'cult',
#   'uncomfortable',
#   'guess',
#   'trump',
#   'teach',
#   'people',
#   'crazy'],
#  ['live', 'drop', 'message', 'moment', 'open'],
#  ['wake'],
#  ['hear',
#   'policy',
#   'choice',
#   'alternative',
#   'party',
#   'hate',
#   'constitution',
#   'already',
#   'literally',
#   'authoritarian',
#   'anti',
#   'promise',
#   'conservative',
#   'choice',
#   'principle'],
#  ['black', 'sheep', 'pretend'],
#  ['truly',
#   'amazing',
#   'guy',
#   'inspiration',
#   'emotional',
#   'watch',
#   'kevinsinfield'],
#  ['ian', 'double', 'life', 'singular', 'purpose', 'dlgfp'],
#  ['stereophonic', 'love', 'drive', 'wale', 'bonus'],
#  ['believe',
#   'half',
#   'hard',
#   'work',
#   'tory',
#   'love',
#   'phrase',
#   'people',
#   'wrong',
#   'grotesquely',
#   'pay',
#   'tory',
#   'mp'],
#  ['happy',
#   'heavenly',
#   'birthday',
#   'big',
#   'sis',
#   'today',
#   'forever',
#   'heart',
#   'obuhbe'],
#  ['start', 'road', 'lineup', 'score', 'underneath'],
#  ['honestly', 'precious', 'omg', 'look'],
#  ['sle', 'racing', 'pvp', 'mode', 'crazy', 'alaskagoldrush'],
#  ['still', 'sweatshirt', 'weather', 'rise', 'grab'],
#  ['add', 'anxiety', 'setlist'],
#  ['lol'],
#  ['ever', 'child', 'seat', 'black', 'people', 'comply', 'stupid', 'law'],
#  ['abduct', 'sheriff', 'bit'],
#  [],
#  ['hear',
#   'reliable',
#   'detailed',
#   'source',
#   'trump',
#   'still',
#   'cic',
#   'charge',
#   'military',
#   'much',
#   'nwo',
#   'agenda',
#   'truly',
#   'nwo',
#   'military',
#   'compromise'],
#  ['hot', 'handle', 'lovely', 'twittersphere'],
#  ['cunt', 'treatment', 'day', 'message', 'fuck', 'irelandisfull'],
#  ['man',
#   'hire',
#   'hitman',
#   'kill',
#   'teen',
#   'send',
#   'express',
#   'image',
#   'day',
#   'information'],
#  ['troll'],
#  ['leave',
#   'block',
#   'send',
#   'arch',
#   'hypocrite',
#   'labourfile',
#   'corbynwasright',
#   'howtobewrong'],
#  ['else', 'explain', 'white', 'today', 'genocide'],
#  ['smash', 'babe'],
#  ['catch', 'ever', 'attempt', 'speak', 'people', 'racist', 'settler'],
#  ...]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

# pprint(model.print_topics())
# save model to disk (no need to use pickle module)
model.save('lda.model')



# print all topics
model.show_topics(2, 20)

# print topic 28
model.print_topic(3, topn=20)

# another way
for i in range(0, model.num_topics-1):
     print(model.print_topic(i))

# and another way, only prints top words
for t in range(0, model.num_topics-1):
    print(  'topic {}: '.format(t) + ', '.join([str(v[1]) for v in model.show_topic(t, 20)]))

logfile = open('../yourfile.txt', 'a')
#print>>logfile, lda.show_topics(topics=-1, topn=10) # for python2
print(logfile, model.show_topics(-1, 10))
for row in model.show_topics(-1,10):
    logfile.write(str(row)+'\n')    
    print(row)
logfile.close()
# Out:
# 0.021*"people" + 0.017*"conservative" + 0.012*"jar" + 0.012*"tory" + 0.012*"new" + 0.011*"work" + 0.011*"vote" + 0.011*"spender" + 0.011*"mdbn" + 0.011*"symon"
# 0.018*"labour" + 0.015*"time" + 0.012*"live" + 0.012*"day" + 0.012*"great" + 0.011*"look" + 0.009*"leave" + 0.009*"bad" + 0.009*"show" + 0.008*"last"
# 0.014*"year" + 0.013*"support" + 0.012*"still" + 0.011*"co" + 0.010*"give" + 0.009*"really" + 0.009*"call" + 0.008*"war" + 0.008*"first" + 0.008*"love"
# topic 0: 0.021421582, 0.017384196, 0.012250794, 0.0121770995, 0.011591191, 0.011275095, 0.0108857695, 0.0106971655, 0.0106971655, 0.0106971655, 0.009864963, 0.009636022, 0.008515352, 0.008195398, 0.008065323, 0.0068882555, 0.006596501, 0.0057821837, 0.005681877, 0.0056744553
# topic 1: 0.017971061, 0.015120967, 0.011982991, 0.011957083, 0.011558291, 0.010794779, 0.009421533, 0.009137441, 0.00892532, 0.007729067, 0.0076976162, 0.0071120025, 0.006223505, 0.006075514, 0.0057301177, 0.0056905593, 0.0056772972, 0.0056006704, 0.005586272, 0.0052919746
# topic 2: 0.01353108, 0.013445499, 0.012400376, 0.0106556695, 0.010354119, 0.009207763, 0.0086524375, 0.007938476, 0.007823343, 0.0077205566, 0.007669773, 0.0071317656, 0.0069870353, 0.006641383, 0.006501075, 0.006270786, 0.006239357, 0.005571511, 0.0053703235, 0.0052943737
# <_io.TextIOWrapper name='../yourfile.txt' mode='a' encoding='cp1252'> [(0, '0.021*"people" + 0.017*"conservative" + 0.012*"jar" + 0.012*"tory" + 0.012*"new" + 0.011*"work" + 0.011*"vote" + 0.011*"spender" + 0.011*"mdbn" + 0.011*"symon"'), (1, '0.018*"labour" + 0.015*"time" + 0.012*"live" + 0.012*"day" + 0.012*"great" + 0.011*"look" + 0.009*"leave" + 0.009*"bad" + 0.009*"show" + 0.008*"last"'), (2, '0.014*"year" + 0.013*"support" + 0.012*"still" + 0.011*"co" + 0.010*"give" + 0.009*"really" + 0.009*"call" + 0.008*"war" + 0.008*"first" + 0.008*"love"'), (3, '0.016*"well" + 0.014*"back" + 0.012*"way" + 0.010*"let" + 0.010*"bring" + 0.009*"world" + 0.009*"never" + 0.009*"stop" + 0.007*"money" + 0.007*"ever"')]
# (0, '0.021*"people" + 0.017*"conservative" + 0.012*"jar" + 0.012*"tory" + 0.012*"new" + 0.011*"work" + 0.011*"vote" + 0.011*"spender" + 0.011*"mdbn" + 0.011*"symon"')
# (1, '0.018*"labour" + 0.015*"time" + 0.012*"live" + 0.012*"day" + 0.012*"great" + 0.011*"look" + 0.009*"leave" + 0.009*"bad" + 0.009*"show" + 0.008*"last"')
# (2, '0.014*"year" + 0.013*"support" + 0.012*"still" + 0.011*"co" + 0.010*"give" + 0.009*"really" + 0.009*"call" + 0.008*"war" + 0.008*"first" + 0.008*"love"')
# (3, '0.016*"well" + 0.014*"back" + 0.012*"way" + 0.010*"let" + 0.010*"bring" + 0.009*"world" + 0.009*"never" + 0.009*"stop" + 0.007*"money" + 0.007*"ever"')

# %%
# Visualize topics with pyLDAvis
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(model, corpus, dictionary)
vis

# Plot WordCloud for each topic
for topic_id in range(num_topics):
    word_freqs = dict(lda_model.show_topic(topic_id, topn=30))
    wordcloud = WordCloud(width=800, height=800, background_color='white').generate_from_frequencies(word_freqs)
    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()
